// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидуальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Person
{
    private string _name;
    private int _age;
    private string _gender;

    public string Name
    {
        get {return _name;}

        set
        {
            if (string.IsNullOrWhiteSpace(value))
            {
                throw new ArgumentException("Имя не может быть пустым");
            }
            else
            {
                _name = value;
            }
        }
    }

    public int Age
    {
        get {return _age;}

        set
        {
            if (value < 0)
            {
                throw new ArgumentException("Возраст не может быть отрицательным");
            }
            else
            {
                _age = value;
            }
        }
    }

    public string Gender
    {
        get {return _gender;}
        set {_gender = value;}
    }

    public Person(string name, int age, string gender)
    {
        Name = name;
        Age = age;
        Gender = gender;
    }

    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Пол: {Gender}";
    }

    public virtual void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}.");
    }

    public void Greeting(Person anotherPerson)
    {
        Console.WriteLine($"{this.Name} поприветствовал {anotherPerson.Name}");
    }
}

// %%
public class Student : Person
{
    public string University {get; set; }
    public string Course {get; set; }

    public Student(string name, int age, string gender, string university, string course)
    : base(name, age, gender)
    {
        University = university;
        Course = course;
    }

    public override void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}, я студент {University}, {Course}.");
    }

}

// %%
public class Employee : Person
{
    public string Company {get; set;}
    public int Salary {get; set;}

    public Employee (string name, int age, string gender, string company, int salary)
    : base (name, age, gender)
    {
        Company = company;
        Salary = salary;
    }

    public override string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Пол: {Gender}, Компания: {Company}, Зарплата: {Salary}";
    }
}

// %%
public class Teacher : Person
{
    public string Subject {get; set;}
    public int Experience {get; set;}

    public Teacher (string name, int age, string gender, string subject, int experience)
    : base (name, age, gender)
    {
        Subject = subject;
        Experience = experience;
    }

    public override void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}, я преподаю {Subject}.");
    }

}

// %%
Student myStudent = new Student("Максим", 20, "Мужской", "МФТИ", "2 курс");
Employee myEmployee = new Employee("Анна", 28, "Женский", "Магнит", 80000);
Teacher myTeacher = new Teacher("Елена", 35, "Женский", "Математика", 10);

List<Person> people = new List<Person>();
people.Add(myStudent);
people.Add(myEmployee);
people.Add(myTeacher);

foreach (Person p in people)
{
    Console.WriteLine(p.GetInfo());
    p.SayHello();
}

myStudent.Greeting(myEmployee); // Максим поприветствовал Елену
// Out:
// Имя: Максим, Возраст: 20, Пол: Мужской
// Привет! Меня зовут Максим, я студент МФТИ, 2 курс.
// Имя: Анна, Возраст: 28, Пол: Женский, Компания: Магнит, Зарплата: 80000
// Привет! Меня зовут Анна.
// Имя: Елена, Возраст: 35, Пол: Женский
// Привет! Меня зовут Елена, я преподаю Математика.
// Максим поприветствовал Анна
